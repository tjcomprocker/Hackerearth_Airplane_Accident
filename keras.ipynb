# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop, Adadelta, Adam
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("train.csv")
#target = pd.DataFrame(columns=["Severity"])
#target["Severity"] = df["Severity"]
target = pd.get_dummies(df["Severity"])
df.drop(["Accident_ID","Severity"],axis=1,inplace=True)
df.shape
# Out:
# (10000, 10)

# %%
x_train, x_val, y_train, y_val = train_test_split(df, target, test_size=0.1, random_state=20)
y_train.shape
# Out:
# (9000, 4)

# %%
model = Sequential()
model.add(Dense(10, input_dim=x_train.shape[1], activation='relu'))
model.add(Dense(9, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(4, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_4 (Dense)              (None, 9)                 99
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 80
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 45
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 24
# ...
# Total params: 358
# Trainable params: 358
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.fit(x_train, y_train, epochs=50, batch_size=64)

scores = model.evaluate(x_val, y_val)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Train on 9000 samples
# Epoch 1/50
# 9000/9000 [==============================] - 1s 108us/sample - loss: 1.3650 - categorical_accuracy: 0.3021
# Epoch 2/50
# 9000/9000 [==============================] - 0s 48us/sample - loss: 1.3650 - categorical_accuracy: 0.3021
# Epoch 3/50
# 9000/9000 [==============================] - 0s 44us/sample - loss: 1.3650 - categorical_accuracy: 0.3021
# Epoch 4/50
# 9000/9000 [==============================] - 0s 44us/sample - loss: 1.3650 - categorical_accuracy: 0.3021
# Epoch 5/50
# 9000/9000 [==============================] - 0s 45us/sample - loss: 1.3650 - categorical_accuracy: 0.3021
# Epoch 6/50
# 9000/9000 [==============================] - 0s 44us/sample - loss: 1.3650 - categorical_accuracy: 0.3021
# Epoch 7/50
# 9000/9000 [==============================] - 0s 44us/sample - loss: 1.3650 - categorical_accuracy: 0.3021
# Epoch 8/50
# 9000/9000 [==============================] - 0s 45us/sample - loss: 1.3650 - categorical_accuracy: 0.3021
# ...

# %%
pred = model.predict(x_val)
ls = [0]*4
total = 0
for point in pred:
    print (tf.math.argmax(point))
    total += 0
print (ls)
# Out:
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# ...
